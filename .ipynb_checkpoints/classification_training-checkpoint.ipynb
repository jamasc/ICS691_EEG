# %%
### model training

# 1. training data preparation. creates an excel sheet:
# ID | diagnosis (GT) | num_label (GT) | gender | age | mmse | path_to_eeg | path_to_feature_vector | biomarkers

# 2. train simple classification model on feature vector + biographics + biomarkers > ad diagnosis

# 3. comparison with other baselines

# %%
### 1. prepare training data

import csv
import pandas as pd
from utility import save_eeg_features_from_path, get_biomarkers_from_path

# path to participants.tsv (from kaggle open nuro dataset)
path = '/home/jans26/.cache/kagglehub/datasets/yosftag/open-nuro-dataset/versions/1/dataset/participants.tsv'

label2num = {
    'C': 0,    # healthy control
    'A': 1,    # alzheimer’s disease 
    'F': 2     # frontotemporal dementia
}

# go thru all patients in tsv and save their data
data = []
with open(path, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f, delimiter='\t')
    for row in reader:
        eeg_id = row['participant_id']
        print(eeg_id)
        diagnosis = row['Group']
        num_label = label2num[row['Group']]
        gender = row['Gender']
        gender_bin = 1 if gender == 'M' else 0
        age = row['Age']
        mmse = row['MMSE']
        path_to_eeg = f'/home/jans26/.cache/kagglehub/datasets/yosftag/open-nuro-dataset/versions/1/dataset/derivatives/{eeg_id}/eeg/{eeg_id}_task-eyesclosed_eeg.set'
        
        # compute and save feature vector, save path in data
        path_to_feature_vector = save_eeg_features_from_path(path_to_eeg, 'eegpt_features', eeg_id)
        # compute and save biomarkers
        alpha, beta, theta, delta, theta_alpha_ratio, slowing_index, coherence, entropy_val = get_biomarkers_from_path(path_to_eeg)
        
        data.append([
            eeg_id, diagnosis, num_label, gender, gender_bin, age, mmse, path_to_eeg, path_to_feature_vector,
            alpha, beta, theta, delta, theta_alpha_ratio, slowing_index, coherence, entropy_val
        ])

columns = [
    "eeg_id", "diagnosis", "num_label", "gender", "gender_bin", "age", "mmse",
    "path_to_eeg", "path_to_feature_vector",
    "alpha", "beta", "theta", "delta",
    "theta_alpha_ratio", "slowing_index", "coherence", "entropy"
]

df = pd.DataFrame(data, columns=columns)

df.to_excel("eeg_dataset.xlsx", index=False)
# Out:
# /mnt/lustre/koa/scratch/jans26/eeg/EEGPT_mcae_finetune.py:679: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(True)
# /mnt/lustre/koa/scratch/jans26/eeg/EEGPT_mcae_finetune.py:693: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(True)
# sub-001
# Effective window size : 0.512 (s)
# sub-002
# Effective window size : 0.512 (s)
# sub-003
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-004
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-005
# Effective window size : 0.512 (s)
# sub-006
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-007
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-008
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-009
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-010
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-011
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-012
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-013
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-014
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-015
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-016
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-017
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-018
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-019
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-020
# Effective window size : 0.512 (s)
# sub-021
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-022
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-023
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-024
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-025
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-026
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-027
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-028
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-029
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-030
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-031
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-032
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-033
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-034
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-035
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-036
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-037
# Effective window size : 0.512 (s)
# sub-038
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-039
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-040
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-041
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-042
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-043
# Effective window size : 0.512 (s)
# sub-044
# Effective window size : 0.512 (s)
# sub-045
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-046
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-047
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-048
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-049
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-050
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-051
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-052
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-053
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-054
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-055
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-056
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-057
# Effective window size : 0.512 (s)
# sub-058
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-059
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-060
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-061
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-062
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-063
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-064
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-065
# Effective window size : 0.512 (s)
# sub-066
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-067
# Effective window size : 0.512 (s)
# sub-068
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-069
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-070
# Effective window size : 0.512 (s)
# sub-071
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-072
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-073
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-074
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-075
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-076
# Effective window size : 0.512 (s)
# sub-077
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-078
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-079
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-080
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-081
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-082
# Effective window size : 0.512 (s)
# sub-083
# Effective window size : 0.512 (s)
# sub-084
# Effective window size : 0.512 (s)
# sub-085
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-086
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-087
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)
# sub-088
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:130: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# /mnt/lustre/koa/scratch/jans26/eeg/utility.py:71: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(eeg_path, preload=True)
# Effective window size : 0.512 (s)

# %%
### 2. training classifier
# dataset that can give me the features and label
# simple nn for classification

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import torch.optim as optim
import pandas as pd
import os

# models
class EmbeddingClassifier(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, embed_vec):
        return self.net(embed_vec)

class TabularClassifier(nn.Module):
    def __init__(self, num_tabular, num_classes):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(num_tabular, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, tabular_vec):
        return self.net(tabular_vec)

class HybridClassifier(nn.Module):
    def __init__(self, num_tabular, num_classes):
        super().__init__()

        # -------- Embedding branch (512 → 128)
        self.embed_net = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU()
        )

        # -------- Tabular branch (~10 → 64)
        self.tabular_net = nn.Sequential(
            nn.Linear(num_tabular, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU()
        )

        # -------- Final classifier
        self.classifier = nn.Sequential(
            nn.Linear(128 + 64, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

        # Learnable scaling (helps prevent tabular being ignored)
        self.alpha = nn.Parameter(torch.tensor(1.0))

    def forward(self, embed_vec, tabular_vec):
        x1 = self.embed_net(embed_vec)       # [B, 128]
        x2 = self.tabular_net(tabular_vec)   # [B, 64]

        x = torch.cat([x1, self.alpha * x2], dim=1)
        return self.classifier(x)

# datasets
class EmbeddingDataset(Dataset):
    def __init__(
        self,
        excel_path,
        label_col,
        embed_col
    ):
        self.df = pd.read_excel(excel_path)

        self.labels = self.df[label_col].values.astype("int64")
        self.embed_paths = self.df[embed_col].values

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        embed_path = self.embed_paths[idx]
        embed = torch.load(embed_path)

        if embed.ndim > 1:
            embed = embed.squeeze()

        embed = embed.float()
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return embed, label

class TabularDataset(Dataset):
    def __init__(
        self,
        excel_path,
        feature_cols,
        label_col,
        normalize=True
    ):
        self.df = pd.read_excel(excel_path)

        self.features = self.df[feature_cols].values.astype("float32")
        self.labels = self.df[label_col].values.astype("int64")

        self.normalize = normalize
        if normalize:
            self.mean = self.features.mean(axis=0)
            self.std = self.features.std(axis=0) + 1e-8

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        tab = self.features[idx]

        if self.normalize:
            tab = (tab - self.mean) / self.std

        tab = torch.tensor(tab, dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return tab, label

class HybridDataset(Dataset):
    def __init__(
        self,
        excel_path,
        feature_cols,
        label_col,
        embed_col,
        normalize=True
    ):
        self.df = pd.read_excel(excel_path)

        self.feature_cols = feature_cols
        self.label_col = label_col
        self.embed_col = embed_col

        # ---- Convert to numpy for speed
        self.features = self.df[feature_cols].values.astype("float32")
        self.labels = self.df[label_col].values.astype("int64")
        self.embed_paths = self.df[embed_col].values

        # ---- Normalization (VERY important)
        self.normalize = normalize
        if normalize:
            self.mean = self.features.mean(axis=0)
            self.std = self.features.std(axis=0) + 1e-8

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # ---- Load embedding
        embed_path = self.embed_paths[idx]
        embed = torch.load(embed_path)  # assumes tensor [512]

        # Safety: ensure correct shape
        if embed.ndim > 1:
            embed = embed.squeeze()

        embed = embed.float()

        # ---- Tabular features
        tab = self.features[idx]

        if self.normalize:
            tab = (tab - self.mean) / self.std

        tab = torch.tensor(tab, dtype=torch.float32)

        # ---- Label
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return embed, tab, label

        
# training + evaluation
def train_embedding(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0

    for embed, y in loader:
        embed = embed.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        logits = model(embed)
        loss = criterion(logits, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(loader)

def train_tabular(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0

    for tab, y in loader:
        tab = tab.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        logits = model(tab)
        loss = criterion(logits, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(loader)
    
def train_hybrid(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0

    for embed, tab, y in loader:
        embed = embed.to(device)
        tab = tab.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        logits = model(embed, tab)
        loss = criterion(logits, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(loader)
    
@torch.no_grad()
def evaluate_simple(model, loader, device):
    model.eval()
    correct = 0
    total = 0

    for batch in loader:
        x, y = batch
        x = x.to(device)
        y = y.to(device)

        logits = model(x)
        preds = torch.argmax(logits, dim=1)

        correct += (preds == y).sum().item()
        total += y.size(0)

    return correct / total

# ============================================
# setup

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

num_tabular = 11     # your float features (including the binary one)
num_classes = 3      # or 2

#model = EmbeddingClassifier(num_classes).to(device)
model = TabularClassifier(num_tabular, num_classes).to(device)
#model = HybridClassifier(num_tabular, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

feature_cols = [
    "gender_bin",
    "age", 
    "mmse",
    "alpha", 
    "beta", 
    "theta", 
    "delta",
    "theta_alpha_ratio", 
    "slowing_index", 
    "coherence", 
    "entropy"
]

#dataset = EmbeddingDataset(
#    excel_path="eeg_dataset.xlsx",
#    label_col="num_label",
#    embed_col="path_to_feature_vector"
#)

dataset = TabularDataset(
    excel_path="eeg_dataset.xlsx",
    feature_cols=feature_cols,
    label_col="num_label",
)

#dataset = HybridDataset(
#    excel_path="eeg_dataset.xlsx",
#    feature_cols=feature_cols,
#    label_col="num_label",
#    embed_col="path_to_feature_vector"
#)

train_size = int(0.75 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)


# training loop

epochs = 50

for epoch in range(epochs):
    train_loss = train_embedding(model, train_loader, optimizer, criterion, device)
#    train_loss = train_tabular(model, train_loader, optimizer, criterion, device)
#    train_loss = train_hybrid(model, train_loader, optimizer, criterion, device)
    val_acc = evaluate_simple(model, val_loader, device)

    print(f"Epoch {epoch+1}/{epochs}")
    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Acc: {val_acc:.4f}")
    print("-" * 40)

torch.save(model.state_dict(), "eeg_classification_model_tabular.pt")
# Out:
# Epoch 1/50
# Train Loss: 1.0600
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 2/50
# Train Loss: 0.9699
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 3/50
# Train Loss: 0.9047
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 4/50
# Train Loss: 0.8316
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 5/50
# Train Loss: 0.8155
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 6/50
# Train Loss: 0.7244
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 7/50
# Train Loss: 0.6361
# Val Acc: 0.7727
# ----------------------------------------
# Epoch 8/50
# Train Loss: 0.5653
# Val Acc: 0.7727
# ----------------------------------------
# Epoch 9/50
# Train Loss: 0.5550
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 10/50
# Train Loss: 0.4795
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 11/50
# Train Loss: 0.4154
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 12/50
# Train Loss: 0.3847
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 13/50
# Train Loss: 0.3810
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 14/50
# Train Loss: 0.3545
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 15/50
# Train Loss: 0.3475
# Val Acc: 0.7273
# ----------------------------------------
# Epoch 16/50
# Train Loss: 0.2855
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 17/50
# Train Loss: 0.2666
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 18/50
# Train Loss: 0.2443
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 19/50
# Train Loss: 0.2242
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 20/50
# Train Loss: 0.2337
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 21/50
# Train Loss: 0.2217
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 22/50
# Train Loss: 0.1921
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 23/50
# Train Loss: 0.1768
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 24/50
# Train Loss: 0.1635
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 25/50
# Train Loss: 0.1689
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 26/50
# Train Loss: 0.1582
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 27/50
# Train Loss: 0.1430
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 28/50
# Train Loss: 0.1383
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 29/50
# Train Loss: 0.1265
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 30/50
# Train Loss: 0.1324
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 31/50
# Train Loss: 0.1447
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 32/50
# Train Loss: 0.1066
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 33/50
# Train Loss: 0.1106
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 34/50
# Train Loss: 0.1511
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 35/50
# Train Loss: 0.0918
# Val Acc: 0.5909
# ----------------------------------------
# Epoch 36/50
# Train Loss: 0.1038
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 37/50
# Train Loss: 0.0854
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 38/50
# Train Loss: 0.0927
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 39/50
# Train Loss: 0.0864
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 40/50
# Train Loss: 0.0709
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 41/50
# Train Loss: 0.0704
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 42/50
# Train Loss: 0.0869
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 43/50
# Train Loss: 0.0661
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 44/50
# Train Loss: 0.0677
# Val Acc: 0.6818
# ----------------------------------------
# Epoch 45/50
# Train Loss: 0.0558
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 46/50
# Train Loss: 0.0550
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 47/50
# Train Loss: 0.0526
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 48/50
# Train Loss: 0.0501
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 49/50
# Train Loss: 0.0452
# Val Acc: 0.6364
# ----------------------------------------
# Epoch 50/50
# Train Loss: 0.0478
# Val Acc: 0.6364
# ----------------------------------------

# %%
# 3. baseline compasrison

import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

def dataset_to_numpy(dataset):
    X_embed, X_tab, y = [], [], []

    for i in range(len(dataset)):
        embed, tab, label = dataset[i]

        X_embed.append(embed.numpy())
        X_tab.append(tab.numpy())
        y.append(label.item())

    return (
        np.array(X_embed),
        np.array(X_tab),
        np.array(y)
    )

X_embed_train, X_tab_train, y_train = dataset_to_numpy(train_dataset)
X_embed_val, X_tab_val, y_val = dataset_to_numpy(val_dataset)

X_train = np.concatenate([X_embed_train, X_tab_train], axis=1)
X_val = np.concatenate([X_embed_val, X_tab_val], axis=1)

print("Train shape:", X_train.shape)
print("Val shape:", X_val.shape)

# A Logistic Regression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_acc = accuracy_score(y_val, lr.predict(X_val))

# B Random Forest

rf = RandomForestClassifier(
    n_estimators=200,
    n_jobs=-1,
    random_state=42
)
rf.fit(X_train, y_train)
rf_acc = accuracy_score(y_val, rf.predict(X_val))

# C Gradient Boosting (STRONG baseline)

gb = HistGradientBoostingClassifier(max_iter=200)
gb.fit(X_train, y_train)
gb_acc = accuracy_score(y_val, gb.predict(X_val))

# D MLP (sklearn NN baseline)

mlp = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    max_iter=200
)
mlp.fit(X_train, y_train)
mlp_acc = accuracy_score(y_val, mlp.predict(X_val))

# E Ablation: Embedding ONLY

lr_embed = LogisticRegression(max_iter=1000)
lr_embed.fit(X_embed_train, y_train)
embed_acc = accuracy_score(y_val, lr_embed.predict(X_embed_val))

# F Ablation: Tabular ONLY

lr_tab = LogisticRegression(max_iter=1000)
lr_tab.fit(X_tab_train, y_train)
tab_acc = accuracy_score(y_val, lr_tab.predict(X_tab_val))

# Results

results = {
    "LogReg (All Features)": lr_acc,
    "Random Forest": rf_acc,
    "Gradient Boosting": gb_acc,
    "MLP (sklearn)": mlp_acc,
    "Embedding Only": embed_acc,
    "Tabular Only": tab_acc
}

print("\n=== BASELINE COMPARISON ===")
for k, v in results.items():
    print(f"{k:25s}: {v:.4f}")
# Out:
# Train shape: (66, 523)
# Val shape: (22, 523)
#
# === BASELINE COMPARISON ===
# LogReg (All Features)    : 0.7727
# Random Forest            : 0.5000
# Gradient Boosting        : 0.7727
# MLP (sklearn)            : 0.6818
# Embedding Only           : 0.3636
# Tabular Only             : 0.7727
# /home/jans26/.conda/envs/myenv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
