# %%
### This script is the complete workflow to get an explanation and diagnosis from eeg data

from preprocessing import preprocess_file, npz_to_raw, preprocess_raw
from biomarkers import extract_features_fast, extract_biomarkers, extract_biomarker_outputs, load_reference_ranges
from feature_extraction import get_mean_eegpt_features
from classification import get_diagnosis, diag2llm
from llm_reasoning import main
import time
import numpy as np

# setup
raw_eeg = "C:\\Users\\marks\\Downloads\\caueeg-dataset\\caueeg-dataset\\signal\\edf\\00756.edf"
y = '?'
age = 69
print(f"Testing subject. Age: {age}, GT: {y}.")

start = time.time()

# preprocess
eeg = preprocess_file(raw_eeg).get_data() 

###
condition = 'photic_stimulation' #"resting_eyes_closed", "resting_eyes_open", "auditory_task", "cognitive_task", "photic_stimulation", "unknown"

# Load the healthy/AD reference ranges for AD pattern predictions
reference = load_reference_ranges("biomarker_reference.npz")

# extract biomarkers + save report
biomarker_features, biomarker_names, biomarker_report = extract_biomarker_outputs(
    eeg,
    condition=condition,
    reference=reference,
    save_to="new_biomarkers.txt",
)

# classification
biomarkers = extract_features_fast(eeg, mode='whole_head')[0][0,:] # need list of numeric values or dict in form {'name_of_bm': val} 
prediction_from_biomarkers, confidence_from_biomarkers = get_diagnosis(biomarkers, age, mode='biomarkers')
features = get_mean_eegpt_features(eeg) # need  segmentsx64
prediction_from_embeddings, confidence_from_embeddings = get_diagnosis(features, age, mode='embeddings')
prediction_text = diag2llm(prediction_from_biomarkers, confidence_from_biomarkers, prediction_from_embeddings, confidence_from_embeddings)
with open ('prediction.txt', 'w') as f:
    f.write(prediction_text)

# explanation
main() 

end = time.time()
print(f"Elapsed time: {end - start:.4f} seconds")
# Out:
# C:\Users\marks\pythonscripts\EEG_final\EEGPT_mcae_finetune.py:679: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(True)
# C:\Users\marks\anaconda3\envs\new-env\Lib\site-packages\torch\cuda\amp\autocast_mode.py:54: UserWarning: CUDA is not available or torch_xla is imported. Disabling autocast.
#   super().__init__(
# C:\Users\marks\pythonscripts\EEG_final\EEGPT_mcae_finetune.py:693: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(True)
# Testing subject. Age: 69, GT: ?.
# Extracting EDF parameters from C:\Users\marks\Downloads\caueeg-dataset\caueeg-dataset\signal\edf\00756.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 132999  =      0.000 ...   664.995 secs...
# Effective window size : 16.000 (s)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (6.602 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# C:\Users\marks\pythonscripts\EEG_final\biomarkers.py:1520: RuntimeWarning: Mean of empty slice
#   result = np.nanmean(arr, axis=0)
# Report saved to: new_biomarkers.txt
# Here's an assessment of the evidence for and against an Alzheimer's Disease diagnosis based on the provided EEG biomarker report and classification models:
#
# **Evidence Supporting an Alzheimer's Diagnosis:**
#
# *   **KDE Feature Classification - Significant Abnormalities:** Several features show a high probability of being associated with Alzheimer's Disease according to the Kernel Density Estimation (KDE) classification:
#     *   `beta_power`: AD=99.76% / NON-AD=0.24%
#     *   `iqr`: AD=100.00% / NON-AD=0.00%
#     *   `max`: AD=100.00% / NON-AD=0.00%
#     *   `mean_abs`: AD=100.00% / NON-AD=0.00%
#     *   `min`: AD=100.00% / NON-AD=0.00%
#     *   `std`: AD=100.00% / NON-AD=0.00%
#     These indicate a strong consistency of these specific feature values with the AD distribution in the model's training data. The near-perfect AD probabilities for `iqr`, `max`, `mean_abs`, `min`, and `std` are particularly striking.
#
# *   **Classification Model - Embedding Model:** The embedding model predicted ALZHEIMERS DISEASE with a confidence of 0.405. While not overwhelmingly strong, this leans towards an AD diagnosis.
#
# **Evidence Contradicting an Alzheimer's Diagnosis:**
#
# *   **EEG Biomarker Report - No Persistent Flags:** The report explicitly states "Persistently flagged features (≥25% of segments AND recording avg abnormal): 0" and "No AD-associated abnormalities detected." This is the strongest piece of evidence contradicting a clear AD diagnosis based on the flag-based EEG analysis. Persistent flags are described as the strongest tier of EEG evidence.
#
# *   **EEG Biomarker Report - No Sub-threshold Findings:** The report also notes "Segments with any AD-like pattern: 0/41 (0%)" and "No AD-associated abnormalities detected." This indicates that even at a lower threshold, no patterns suggestive of AD were identified in the individual segments.
#
# *   **EEG Biomarker Report - AD Indicator Summary:** The summary states "No reference ranges provided, or all features within healthy reference ranges," which further suggests a lack of overt EEG abnormalities detected by the system.
#
# *   **Classification Model - Biomarker Model:** The biomarker model predicted HEALTHY with a confidence of 0.515. This suggests that, based on the calculated biomarkers, the model leans towards a healthy classification, contradicting the embedding model's prediction.
#
# **Predicted Diagnosis:**
#
# Based on the provided information, the EEG data does not exhibit clear, consistent patterns indicative of Alzheimer's Disease according to the flag-based analysis (no persistent or sub-threshold findings). However, the KDE feature classification shows strong correlations with AD for several features, and one of the classification models suggests a possibility of AD. The conflicting signals between the flag-based analysis and the KDE/classification models create uncertainty.
#
# **Certainty of Diagnosis:**
#
# Low.
#
# While the KDE results for some features are strongly suggestive of AD, the absence of any persistent or sub-threshold flags is a significant counterpoint. The conflicting predictions from the two classification models further highlight this uncertainty. Therefore, while there are some indicators pointing towards AD, the overall EEG profile is not definitively diagnostic of Alzheimer's Disease based on this report. Further clinical correlation and potentially more sensitive diagnostic methods would be necessary for a definitive diagnosis.
# Elapsed time: 41.2533 seconds
